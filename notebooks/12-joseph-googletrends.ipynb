# %%
import gtab
t = gtab.GTAB(dir_path="gtab_data")
# Out:
# Using directory 'gtab_data'
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2019-01-01 2020-08-01.tsv

# %%
t.set_options(pytrends_config={"geo": "", "timeframe": "2020-01-01 2022-10-01"},
              gtab_config= {"num_anchors": 100})

# %%
t.create_anchorbank()
# Out:
# Start AnchorBank init for region  in timeframe 2020-01-01 2022-10-01...
# 0/118 keyword candidates found in cache, 118 still to check.
# Sampling keywords...
#   5%|▌         | 6/118 [00:09<02:53,  1.55s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 t.create_anchorbank()
#
# File ~/.conda/envs/jyl2fbedge/lib/python3.9/site-packages/gtab/core.py:871, in GTAB.create_anchorbank(self, verbose, keep_diagnostics)
#     868 fname_base = os.path.join(self.dir_path, "output", "google_anchorbanks",
#     869                           f"google_anchorbank_{self._make_file_suffix()}.tsv")
#     870 if not os.path.exists(fname_base):
# --> 871     google_results = self._get_google_results()
#     872     if keep_diagnostics:
#     873         self.google_results = google_results
#
# File ~/.conda/envs/jyl2fbedge/lib/python3.9/site-packages/gtab/core.py:325, in GTAB._get_google_results(self)
#     323 for kw in tqdm(remaining_keywords, total=len(remaining_keywords)):
#     324     try:
# --> 325         keywords_with_status[kw] = self._check_keyword(kw, retry_on_429=True)
#     326     except Exception as e:
#     327         with open(fpath_intermediate_keywords, 'wb') as f_in:
#
# File ~/.conda/envs/jyl2fbedge/lib/python3.9/site-packages/gtab/core.py:143, in GTAB._check_keyword(self, keyword, retry_on_429)
#     141 time.sleep(self.CONFIG['GTAB']['sleep'])
#     142 try:
# --> 143     rez = self._query_google(keywords=keyword)
#     144     return self._is_not_blacklisted(keyword) and not rez.empty
#     145 except ValueError as e:
#
# File ~/.conda/envs/jyl2fbedge/lib/python3.9/site-packages/gtab/core.py:120, in GTAB._query_google(self, keywords)
#     119 def _query_google(self, keywords=["Keywords"]):
# --> 120     time.sleep(self.CONFIG['GTAB']['sleep'])
#     121     if type(keywords) == str:
#     122         keywords = [keywords]
#
# KeyboardInterrupt:

# %%
t.set_active_gtab("google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv")
# Out:
# Active anchorbank changed to: google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv

# %%
import pandas as pd
netflix_titles = pd.read_csv('../data/processed/feed_into_pipeline.csv')

# %%
netflix_titles[netflix_titles['combined_title'].str.contains("The Queen's")]
# Out:
#                           combined_title  release_year release_date  is_top10  \
# 415          Creating The Queen's Gambit          2021   2021-01-08         0
# 1902  The Queen's Gambit: Limited Series          2020   2020-10-23         1
#
#                            lower_title  season  is_tv_show      tconst  \
# 415         creating the queens gambit     NaN       False  tt13818410
# 1902  the queens gambit limited series     1.0        True  tt10048342
#
#       averageRating  numVotes     titleType  runtimeMinutes  \
# 415             6.9       636         short            14.0
# 1902            8.6    440149  tvMiniSeries            60.0
#
#                  genres  seasons  release_date_quarter  release_date_month  \
# 415   Documentary,Short      NaN                     1                   1
# 1902              Drama      NaN                     4                  10
#
#       release_date_week
# 415                   1
# 1902                 43

# %%
imdb_titles = pd.read_csv('../data/external/title.basics.tsv', sep='\t')
# Out:
# C:\Users\Joeyz\AppData\Local\Temp\ipykernel_12348\1750675212.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   imdb_titles = pd.read_csv('../data/external/title.basics.tsv', sep='\t')

# %%
imdb_titles.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
orig_netflix_titles = netflix_titles.merge(imdb_titles[['tconst', 'originalTitle', 'primaryTitle']], left_on='tconst', right_on='tconst', how='left')

# %%
orig_netflix_titles
# Out:
#                                     combined_title  release_year release_date  \
# 0                               #blackAF: Season 1          2020   2020-04-17
# 1                               (Un)Well: Season 1          2020   2020-08-12
# 2                         10 Days With Santa Claus          2020   2020-12-04
# 3                             100 Humans: Season 1          2020   2020-03-13
# 4                        1000 Miles from Christmas          2021   2021-12-24
# ...                                            ...           ...          ...
# 2216                    jeen-yuhs: A Kanye Trilogy          2022   2022-02-16
# 2217   the goop lab with Gwyneth Paltrow: Season 1          2020   2020-01-24
# 2218                            tick, tick...BOOM!          2021   2021-11-19
# 2219                                       Òlòtūré          2020   2020-10-02
# 2220  ​SAINT SEIYA: Knights of the Zodiac: Part II          2020   2020-01-23
#
#       is_top10                                lower_title  season  is_tv_show  \
# 0            0                                    blackaf     1.0        True
# 1            0                                     unwell     1.0        True
# 2            0                   10 days with santa claus     NaN       False
# 3            0                                 100 humans     1.0        True
# 4            1                  1000 miles from christmas     NaN       False
# ...        ...                                        ...     ...         ...
# 2216         1                   jeenyuhs a kanye trilogy     1.0        True
# 2217         0          the goop lab with gwyneth paltrow     1.0        True
# 2218         1                              tick tickboom     NaN       False
# 2219         0                                    òlòtūré     NaN       False
# 2220         1  saint seiya knights of the zodiac part ii     2.0        True
#
#           tconst  averageRating  numVotes     titleType  runtimeMinutes  \
# 0     tt10311562            6.8      4915      tvSeries            36.0
# 1     tt12759384            6.4      1099      tvSeries             NaN
# 2     tt10803866            6.1       860         movie           100.0
# 3     tt11823088            5.8      4179      tvSeries             NaN
# 4     tt13782052            5.8      1552         movie           102.0
# ...          ...            ...       ...           ...             ...
# 2216  tt14599438            8.0      9215  tvMiniSeries            90.0
# 2217  tt11561206            2.6      3361      tvSeries            30.0
# 2218   tt8721424            7.5    104869         movie           120.0
# 2219   tt9725830            5.6       817         movie           106.0
# 2220   tt6908976            4.6      1921      tvSeries            24.0
#
#                           genres  seasons  release_date_quarter  \
# 0                         Comedy      NaN                     2
# 1                    Documentary      NaN                     3
# 2                  Comedy,Family      NaN                     4
# 3                     Reality-TV      NaN                     1
# 4                 Comedy,Romance      NaN                     4
# ...                          ...      ...                   ...
# 2216           Documentary,Music      NaN                     1
# 2217      Documentary,Reality-TV      NaN                     1
# 2218     Biography,Drama,Musical      NaN                     4
# 2219                 Crime,Drama      NaN                     4
# 2220  Action,Adventure,Animation      NaN                     1
#
#       release_date_month  release_date_week  \
# 0                      4                 16
# 1                      8                 33
# 2                     12                 49
# 3                      3                 11
# 4                     12                 51
# ...                  ...                ...
# 2216                   2                  7
# 2217                   1                  4
# 2218                  11                 46
# 2219                  10                 40
# 2220                   1                  4
#
#                             originalTitle  \
# 0                                #BlackAF
# 1                                (Un)Well
# 2              10 giorni con Babbo Natale
# 3                              100 Humans
# 4          A mil kilómetros de la Navidad
# ...                                   ...
# 2216           Jeen-yuhs: A Kanye Trilogy
# 2217                         The Goop Lab
# 2218                   tick, tick...BOOM!
# 2219                              Òlòturé
# 2220  Seinto Seiya: Knights of the Zodiac
#
#                                  primaryTitle
# 0                                    #BlackAF
# 1                                    (Un)Well
# 2         When Mom Is Away... With the Family
# 3     100 Humans: Life's Questions. Answered.
# 4                   1000 Miles from Christmas
# ...                                       ...
# 2216               Jeen-yuhs: A Kanye Trilogy
# 2217                             The Goop Lab
# 2218                      tick, tick... BOOM!
# 2219                                  Òlòtūré
# 2220       Knights of the Zodiac: Saint Seiya
#
# [2221 rows x 19 columns]

# %%
2221/5
# Out:
# 444.2

# %%
orig_netflix_titles['originalTitle'][1:].values.reshape(-1, 5).shape
# Out:
# (444, 5)

# %%
orig_netflix_titles['originalTitle'].values.reshape(-1, 1)
# Out:
# array([['#BlackAF'],
#        ['(Un)Well'],
#        ['10 giorni con Babbo Natale'],
#        ...,
#        ['tick, tick...BOOM!'],
#        ['Òlòturé'],
#        ['Seinto Seiya: Knights of the Zodiac']], dtype=object)

# %%
t.new_query("queen's gambit")
# Out:
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'queen's gambit'
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 878 (2 times)]
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:868, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     867 try:
# --> 868     retries = retries.increment(method, url, response=response, _pool=self)
#     869 except MaxRetryError:
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22%2Fm%2F05c5y0b%22%2C+%22time%22%3A+%222020-01-01+2022-10-01%22%2C+%22geo%22%3A+%22%22%7D%2C+%7B%22keyword%22%3A+%22queen%27s+gambit%22%2C+%22time%22%3A+%222020-01-01+2022-10-01%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\gtab\core.py:989, in GTAB.new_query(self, query, first_comparison, thresh, verbose, complete)
#     988 try:
# --> 989     ts = self._query_google(keywords=[anchor, query]).iloc[:, 0:2]
#     990 except ValueError as e:
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\gtab\core.py:133, in GTAB._query_google(self, keywords)
#     132 else:
# --> 133     self.pytrends.build_payload(kw_list=keywords, **self.CONFIG['PYTRENDS'])
#     134     ret = self.pytrends.interest_over_time()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytrends\request.py:179, in TrendReq.build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     178 # get tokens
# --> 179 self._tokens()
#     180 return
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytrends\request.py:185, in TrendReq._tokens(self)
#     184 # make the request and parse the returned json
# --> 185 widget_dicts = self._get_data(
#     186     url=TrendReq.GENERAL_URL,
#     187     method=TrendReq.GET_METHOD,
#     188     params=self.token_payload,
#     189     trim_chars=4,
#     190 )['widgets']
#     191 # order of the json matters...
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytrends\request.py:136, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     135 else:
# --> 136     response = s.get(url, timeout=self.timeout, cookies=self.cookies,
#     137                      **kwargs, **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     138 # check if the response contains json and throw an exception otherwise
#     139 # Google mostly sends 'application/json' in the Content-Type header,
#     140 # but occasionally it sends 'application/javascript
#     141 # and sometimes even 'text/javascript
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\adapters.py:556, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     555 if isinstance(e.reason, ResponseError):
# --> 556     raise RetryError(e, request=request)
#     558 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22%2Fm%2F05c5y0b%22%2C+%22time%22%3A+%222020-01-01+2022-10-01%22%2C+%22geo%22%3A+%22%22%7D%2C+%7B%22keyword%22%3A+%22queen%27s+gambit%22%2C+%22time%22%3A+%222020-01-01+2022-10-01%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [189], line 1
# ----> 1 t.new_query("queen's gambit")
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\gtab\core.py:994, in GTAB.new_query(self, query, first_comparison, thresh, verbose, complete)
#     992 except Exception as e:
#     993     if "response" in dir(e):
# --> 994         if e.response.status_code == 429:
#     995             input("Quota reached! Please change IP and press enter to continue.")
#     996             ts = self._query_google(keywords=[anchor, query]).iloc[:, 0:2]
#
# AttributeError: 'NoneType' object has no attribute 'status_code'

# %%
mylist = []
for i in orig_netflix_titles['originalTitle']:
    mylist.append(t.new_query(i))
# Out:
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '#BlackAF'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '(Un)Well'
# Keyword (Un)Well is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '10 giorni con Babbo Natale'
# Keyword 10 giorni con Babbo Natale is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '100 Humans'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A mil kilómetros de la Navidad'
# Keyword A mil kilómetros de la Navidad is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '11M'
# Keyword 11M is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '13 Reasons Why'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '137 Shots'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '13: The Musical'
# Keyword 13: The Musical is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '14 Peaks: Nothing Is Impossible'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '18 regali'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '3%'
# Keyword 3% is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '365 Days: This Day'
# Keyword 365 Days: This Day is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '37 sekanzu'
# Keyword 37 sekanzu is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Cuarentones'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '42 Días en la Oscuridad'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '50M2'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '7 Prisioneiros'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '7Seeds'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '8'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query '800 metros'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Babysitter's Guide to Monster Hunting'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Boy Called Christmas'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A California Christmas'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A California Christmas: City Lights'
# Keyword A California Christmas: City Lights is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Castle for Christmas'
# Keyword A Castle for Christmas is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Classic Horror Story'
# Keyword A Classic Horror Story is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Una película de policías'
# Keyword Una película de policías is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Cut Above'
# Keyword A Cut Above is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Fall from Grace'
# Keyword A Fall from Grace is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Yakuza and the Family'
# Keyword Yakuza and the Family is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Go! Go! Cory Carson Christmas'
# Keyword A Go! Go! Cory Carson Christmas is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Go! Go! Cory Carson Halloween'
# Keyword A Go! Go! Cory Carson Halloween is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Go! Go! Cory Carson: Summer Camp'
# Keyword Go! Go! Cory Carson: Summer Camp is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'El caso Cassez-Vallarta: Una novela criminal'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fangio: El hombre que domaba las máquinas'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Love So Beautiful'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Love Song for Latasha'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Madea Homecoming'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Model Family'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Naija Christmas'
# Keyword A Naija Christmas is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Perfect Crime'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Perfect Fit'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Perfect Pairing'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Nasce Uma Rainha'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Second Chance: Rivals!'
# Keyword A Second Chance: Rivals! is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Secret Love'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Colonia Dignidad - Aus dem Innern einer deutschen Sekte'
# Keyword Colonia Dignidad - Aus dem Innern einer deutschen Sekte is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A StoryBots Space Adventure'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Suitable Boy'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Tale Dark & Grimm'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Trash Truck Christmas'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Week Away'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Nakitai watashi wa neko o kaburu'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A World Without'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'AJ and the Queen'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'AK vs AK'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Abla Fahita: Drama Queen'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Absurd Planet'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Action Pack'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Action Pack'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ada Twist, Scientist'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ada Twist, Scientist'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Adam by Eve: A live in Animation'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Adventure Beast'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Adú'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Afonso Padilha: Alma de Pobre'
# Keyword Afonso Padilha: Alma de Pobre is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'After Life'
# Keyword After Life is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'After Life'
# Keyword After Life is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'After We Collided'
# Keyword After We Collided is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'After We Fell'
# Keyword After We Fell is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Afterlife of the Party'
# Keyword Afterlife of the Party is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Against the Ice'
# Keyword Against the Ice is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Age of Samurai: Battle for Japan'
# Keyword Age of Samurai: Battle for Japan is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Aggretsuko'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Aggretsuko'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Modo Avião'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ajeeb Daastaans'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'AlRawabi School for Girls'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alan Saldaña: Locked Up'
# Keyword Alan Saldaña: Locked Up is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alba'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alchemy of Souls'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alessandro Cattelan: One Simple Question'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alex Fernández: El mejor comediante del mundo'
# Keyword Alex Fernández: El mejor comediante del mundo is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alexa & Katie'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ali & the Queens'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ali Wong: Don Wong'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alice in Borderland'
# Keyword Alice in Borderland is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alien TV'
# Keyword Alien TV is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alien TV'
# Keyword Alien TV is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alien Worlds'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alien Xmas'
# Keyword Alien Xmas is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Todo es Gila'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'All Because of You'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'All Day and a Night'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Amar y Vivir'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Granizo'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Wszyscy moi przyjaciele nie zyja'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'All the Bright Places'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'All Together Now'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ji-geum u-ri hak-gyo-neun'
# Keyword Ji-geum u-ri hak-gyo-neun is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Todas las pecas del mundo'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Casi feliz'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Casi feliz'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alone'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Along for the Ride'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Alter Me'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Altered Carbon: Resleeved'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Altered Carbon'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Siempre Bruja'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Amandla'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Amend: The Fight for America'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'America's Got Talent'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'America's Got Talent'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'America's Got Talent'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'America's Got Talent: The Champions'
# Keyword America's Got Talent: The Champions is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'America: The Motion Picture'
# Keyword America: The Motion Picture is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'American Idol: The Search for a Superstar'
# Keyword American Idol: The Search for a Superstar is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'American Idol: The Search for a Superstar'
# Keyword American Idol: The Search for a Superstar is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'American Idol: The Search for a Superstar'
# Keyword American Idol: The Search for a Superstar is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'American Murder: The Family Next Door'
# Keyword American Murder: The Family Next Door is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Amina'
# Keyword Amina is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Amit Tandon: Family Tandoncies'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Amy Schumer's Parental Advisory'
# Keyword Amy Schumer's Parental Advisory is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Guida astrologica per cuori infranti'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Guida astrologica per cuori infranti'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Chichipatos: ¡Qué chimba de Navidad!'
# Keyword Chichipatos: ¡Qué chimba de Navidad! is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Anatomy of a Scandal'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Und morgen die ganze Welt'
# Keyword Und morgen die ganze Welt is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Anelka: Misunderstood'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Angry Birds: Summer Madness'
# Keyword Angry Birds: Summer Madness is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Angry Birds: Summer Madness'
# Keyword Angry Birds: Summer Madness is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Angry Birds: Summer Madness'
# Keyword Angry Birds: Summer Madness is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Angèle'
# Keyword Angèle is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Animal Crackers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Animal'
# Keyword Animal is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Animal'
# Keyword Animal is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Animals on the Loose: A You vs. Wild Movie'
# Keyword Animals on the Loose: A You vs. Wild Movie is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Anitta: Made in Honório'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ankahi Kahaniya'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Anne+'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Anónima'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Another Life'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Another Self'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Folk med ångest'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Apollo 10 1/2: A Space Age Adventure'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Aranyak'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Arcane: League of Legends'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Archibald's Next Big Thing Is Here'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Archibald's Next Big Thing Is Here'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Archibald's Next Big Thing'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Archive 81'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ares'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Pardon My Icelandic'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Arlo the Alligator Boy'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Army of Thieves'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Army of the Dead'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Kus Uçusu'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Asakusa kiddo'
# Keyword Asakusa kiddo is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ashley Garcia: Genius in Love'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Athlete A'
# Keyword Athlete A is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Attack of the Hollywood Cliches!'
# Keyword Attack of the Hollywood Cliches! is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Atypical'
# Keyword Atypical is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Audible'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Aunty Donna's Big Ol' House of Fun'
# Keyword Aunty Donna's Big Ol' House of Fun is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bo we mnie jest seks'
# Keyword Bo we mnie jest seks is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ava'
# Keyword Ava is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Away'
# Keyword Away is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Azcárate: No Holds Barred'
# Keyword Azcárate: No Holds Barred is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Aziz Ansari: Nightclub Comedian'
# Keyword Aziz Ansari: Nightclub Comedian is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'B: The Beginning'
# Could not calibrate. Time series for query too low everywhere.
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Baki'
# Keyword Baki is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Basutado!! Ankoku no hakaishin'
# Keyword Basutado!! Ankoku no hakaishin is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Beastars'
# Keyword Beastars is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Beauty'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blackpink: Light Up the Sky'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'BNA'
# Keyword BNA is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bob Biswas'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bonding'
# Keyword Bonding is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Break It All: The History of Rock in Latin America'
# Keyword Break It All: The History of Rock in Latin America is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Babies'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Babies'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Skruk'
# Keyword Skruk is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Baby'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Babylon Berlin'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'De Volta aos 15'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Back to the Outback'
# Keyword Back to the Outback is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bogdan Boner: Egzorcysta'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bogdan Boner: Egzorcysta'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bad Sport'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bad Trip'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bad Vegan: Fame. Fraud. Fugitives.'
# Keyword Bad Vegan: Fame. Fraud. Fugitives. is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Il Divin Codino'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bake Squad'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Hanma Baki: Son of Ogre'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Baking Impossible'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bangkok Breaking'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Los Ladrones: La verdadera historia del robo del siglo'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fondeados'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Barbarians'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bartkowiak'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Battle Kitty'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Battle: Freestyle'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Beats'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Beckett'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Becoming'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Behind Her Eyes'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Behind the Scenes with Jane Campion'
# Keyword Behind the Scenes with Jane Campion is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bajocero'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Ben Platt Live from Radio City Music Hall'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Berlin, Berlin'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bert Kreischer: Hey Big Boy'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Best Leftovers Ever!'
# Keyword Best Leftovers Ever! is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Best of Stand-up 2020'
# Keyword Best of Stand-up 2020 is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Betaal'
# Could not calibrate. Time series for query too low everywhere.
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Better Call Saul'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Better Call Saul'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bhaag Beanie Bhaag'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Big Mouth'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Big Mouth'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Big Timber'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Big Timber'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Big Tree City'
# Keyword Big Tree City is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'BigBug'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bigflo & Oli: Hip Hop Frenzy'
# Keyword Bigflo & Oli: Hip Hop Frenzy is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bigfoot Family'
# Keyword Bigfoot Family is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Biggie: I Got a Story to Tell'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bill Burr Presents: Friends Who Kill'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bill Burr: Live at Red Rocks'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Biohackers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Biohackers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'O sabor das margaridas'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Black Beach'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Svart krabba'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Schwarze Insel'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Black Lightning'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Black Space'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Black Summer'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blasted: Gutta vs aliens'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bling Empire'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bling Empire'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blood & Water'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blood & Water'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blood Brothers: Malcolm X & Muhammad Ali'
# Keyword Blood Brothers: Malcolm X & Muhammad Ali is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blood Red Sky'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blood Sisters'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blood Ties'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blood of Zeus'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bloodride'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blown Away: Christmas'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blown Away'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blown Away'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blue Miracle'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Blue Period'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bo Burnham: Inside'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bob Ross: Happy Accidents, Betrayal & Greed'
# Keyword Bob Ross: Happy Accidents, Betrayal & Greed is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bombay Begums'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bombay Rose'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bonusfamiljen'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Boo, Bitch'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bookmarks: Celebrating Black Voices'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Borgen'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Brahms: The Boy II'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Brand New Cherry Flavor'
# Keyword Brand New Cherry Flavor is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Brave New World'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Brazen'
# Keyword Brazen is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Break Point'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Breaking Boundaries: The Science of Our Planet'
# Keyword Breaking Boundaries: The Science of Our Planet is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Brews Brothers'
# Keyword Brews Brothers is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Brian Regan: On the Rocks'
# Keyword Brian Regan: On the Rocks is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bridgerton'
# Keyword Bridgerton is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bridgerton'
# Keyword Bridgerton is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bright: Samurai Soul'
# Keyword Bright: Samurai Soul is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Britney vs Spears'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Broken Idol: The Undoing of Diomedes Diaz'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Irmandade'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bruised'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bruna Louise: Demolição'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Buba'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Baburu'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Buddi'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Buddi'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bulbbul'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bulgasal'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Bullsh*t the Game Show'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Buried by the Bernards'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'A Buisness Proposal'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Busted! I Know Who You Are!'
# Keyword Busted! I Know Who You Are! is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Buy My House'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Byron Baes'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Børning 3'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Las chicas del cable'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Kadaver'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Cafe Minamdang'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Café con aroma de mujer'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Mushikago no Cagaster'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Kalifat'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Call My Agent Bollywood'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Camp Confidential: America's Secret Nazis'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'M'entends-tu?'
# Keyword M'entends-tu? is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Can You Hear Me?'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Candyman'
# ...
# New query 'Extraction'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Extracurricular'
# Keyword Extracurricular is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'I-sang-han byeon-ho-sa U-yeong-u'
# Keyword I-sang-han byeon-ho-sa U-yeong-u is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'F Is for Family'
# Keyword F Is for Family is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'F Is for Family'
# Keyword F Is for Family is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'F*ck de liefde 2'
# Keyword F*ck de liefde 2 is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fabulous Lives of Bollywood Wives'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fabulous Lives of Bollywood Wives'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fakes'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Falling for Figaro'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Family Business'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Family Business'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Family Reunion'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Family Reunion'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Family Reunion'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Gry rodzinne'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fanático'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fary: Hexagone'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Farzar'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fast & Furious Spy Racers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fast & Furious Spy Racers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fast & Furious Spy Racers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fast & Furious Spy Racers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fast & Furious Spy Racers'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fatal Affair'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fate: The Winx Saga - The Afterparty'
# Keyword Fate: The Winx Saga - The Afterparty is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fate: The Winx Saga'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Father Christmas Is Back'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Father Soldier Son'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fatherhood'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fatma'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fauda'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fear City: New York vs the Mafia'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fear Street: 1994'
# Keyword Fear Street: 1994 is bad!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fear Street: 1978'
# New query calibrated!
# Using gtab_data\output\google_anchorbanks\google_anchorbank_geo=_timeframe=2020-01-01 2022-10-01.tsv
# New query 'Fear Street: 1666'
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 878 (2 times)]
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\connectionpool.py:868, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     867 try:
# --> 868     retries = retries.increment(method, url, response=response, _pool=self)
#     869 except MaxRetryError:
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Fear+Street%3A+1666%22%2C+%22time%22%3A+%222020-01-01+2022-10-01%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# Cell In [158], line 3
#       1 mylist = []
#       2 for i in orig_netflix_titles['originalTitle']:
# ----> 3     mylist.append(t.new_query(i))
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\gtab\core.py:975, in GTAB.new_query(self, query, first_comparison, thresh, verbose, complete)
#     968 anchors = tuple(self.anchor_bank.index)
#     970 # if query in anchors:
#     971 #     self._print_and_log(f"The query is already present in the active gtab!")
#     972 #     self._log_con.close()
#     973 #     return -2
# --> 975 if not self._check_keyword(query):
#     976     self._print_and_log(f"Keyword {query} is bad!")
#     977     return -1
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\gtab\core.py:157, in GTAB._check_keyword(self, keyword, retry_on_429)
#     155         self._print_and_log(f"\nBad keyword '{keyword}', because {e}")
#     156     else:
# --> 157         raise e
#     158 return False
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\gtab\core.py:143, in GTAB._check_keyword(self, keyword, retry_on_429)
#     141 time.sleep(self.CONFIG['GTAB']['sleep'])
#     142 try:
# --> 143     rez = self._query_google(keywords=keyword)
#     144     return self._is_not_blacklisted(keyword) and not rez.empty
#     145 except ValueError as e:
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\gtab\core.py:133, in GTAB._query_google(self, keywords)
#     131     ret.insert(loc=1, column="tmp", value=ret.iloc[:, 0])
#     132 else:
# --> 133     self.pytrends.build_payload(kw_list=keywords, **self.CONFIG['PYTRENDS'])
#     134     ret = self.pytrends.interest_over_time()
#     135 return ret
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytrends\request.py:179, in TrendReq.build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     177 self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     178 # get tokens
# --> 179 self._tokens()
#     180 return
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytrends\request.py:185, in TrendReq._tokens(self)
#     183 """Makes request to Google to get API tokens for interest over time, interest by region and related queries"""
#     184 # make the request and parse the returned json
# --> 185 widget_dicts = self._get_data(
#     186     url=TrendReq.GENERAL_URL,
#     187     method=TrendReq.GET_METHOD,
#     188     params=self.token_payload,
#     189     trim_chars=4,
#     190 )['widgets']
#     191 # order of the json matters...
#     192 first_region_token = True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pytrends\request.py:136, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     132     response = s.post(url, timeout=self.timeout,
#     133                       cookies=self.cookies, **kwargs,
#     134                       **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     135 else:
# --> 136     response = s.get(url, timeout=self.timeout, cookies=self.cookies,
#     137                      **kwargs, **self.requests_args)  # DO NOT USE retries or backoff_factor here
#     138 # check if the response contains json and throw an exception otherwise
#     139 # Google mostly sends 'application/json' in the Content-Type header,
#     140 # but occasionally it sends 'application/javascript
#     141 # and sometimes even 'text/javascript
#     142 if response.status_code == 200 and 'application/json' in \
#     143         response.headers['Content-Type'] or \
#     144         'application/javascript' in response.headers['Content-Type'] or \
#    (...)
#     147     # some responses start with garbage characters, like ")]}',"
#     148     # these have to be cleaned before being passed to the json parser
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\requests\adapters.py:556, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     553         raise ConnectTimeout(e, request=request)
#     555 if isinstance(e.reason, ResponseError):
# --> 556     raise RetryError(e, request=request)
#     558 if isinstance(e.reason, _ProxyError):
#     559     raise ProxyError(e, request=request)
#
# RetryError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22Fear+Street%3A+1666%22%2C+%22time%22%3A+%222020-01-01+2022-10-01%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+%220%22%2C+%22property%22%3A+%22%22%7D (Caused by ResponseError('too many 429 error responses'))

# %%
myfilt = (mylist[4].index - pd.to_datetime(test1['release_date'])) < pd.Timedelta('0 days')
(mylist[4].index - pd.to_datetime(test1['release_date']))[myfilt].argmax()
# Out:
# 102

# %%
mylist[4].iloc[[100, 101, 102, 103]]
# Out:
#             max_ratio  max_ratio_hi  max_ratio_lo
# date
# 2021-12-05   0.000000      0.000331      0.000000
# 2021-12-12   0.001894      0.002319      0.001504
# 2021-12-19   0.032205      0.034121      0.030377
# 2021-12-26   0.063147      0.066254      0.060152

# %%
abs(mylist[4].index - pd.to_datetime(test1['release_date'])).argsort()[:3]
# Out:
# array([103, 102, 104], dtype=int64)

# %%
mylist[4].iloc[abs(mylist[4].index - pd.to_datetime(test1['release_date'])).argsort()[:3]]
# Out:
#             max_ratio  max_ratio_hi  max_ratio_lo
# date
# 2021-12-26   0.063147      0.066254      0.060152
# 2021-12-19   0.032205      0.034121      0.030377
# 2022-01-02   0.008209      0.008944      0.007519

# %%
get_closest_date(mylist[0], test1['release_date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [71], line 1
# ----> 1 get_closest_date(mylist[0], test1['release_date'])
#
# Cell In [70], line 3, in get_closest_date(df, date)
#       2 def get_closest_date(df, date):
# ----> 3     return df.iloc[(df['date']-date).abs().argsort()[:1]]
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\ProgramData\Miniconda3\envs\netflix_proj\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'date'
